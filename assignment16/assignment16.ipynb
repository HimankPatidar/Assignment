# %% [markdown]
#  We have shared a dataset on which you will have to perform
# Data analysis with pandas, matplotlib and seaborn. And please
# make sure create all charts that we have teach in our previous
# class. And code should be with well commented. And Mention
# your theoretical observation in comment what you will
# observed by the charts. And try with different columns and
# different charts.

# %%
# Importing the pandas library, which is used for data manipulation and analysis
import pandas as pd

# Importing the matplotlib library, which is used for creating static, animated, and interactive visualizations in Python
import matplotlib.pyplot as plt

# Importing the seaborn library, which is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
import seaborn as sns

# Reading a CSV file named 'StudentsPerformance.csv' into a DataFrame named 'df'. The file is located in the current directory.
df = pd.read_csv('./StudentsPerformance.csv')

# Displaying the first 10 rows of the DataFrame 'df'
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
# a 
sns.relplot(x="race/ethnicity", y="lunch", data = df, hue="gender", )

# %%
sns.catplot(x="gender" ,y="math score", data=df, kind="bar")

# %%
sns.catplot(x="test preparation course" ,y="reading score", data=df, kind="bar", hue="gender")

# %%
sns.catplot(x="test preparation course" ,y="writing score", data=df, kind="violin", hue="gender")

# %%
sns.catplot(x="test preparation course" ,y="math score", data=df, kind="swarm", hue="gender")
# Out:
# c:\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 13.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 8.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 14.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x="lunch" ,y="math score", data=df, kind="bar", hue="gender")

# %%
sns.catplot(x="lunch" ,y="reading score", data=df, kind="box", hue="gender")

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
sns.catplot(x="parental level of education" ,y="reading score", data=df, kind="swarm", hue="gender")

# %%
gender_counts = df['gender'].value_counts()

plt.figure(figsize=(10,6))
plt.pie(gender_counts, labels = gender_counts.index, autopct='%1.1f%%')
plt.title('Pie chart of gender')
plt.show()# Bin the scores into categories
df['math_score_bin'] = pd.cut(df['math score'], bins=[0, 50, 75, 100], labels=['Low', 'Medium', 'High'])

# %%
# Create a pie chart for the binned scores
math_score_counts = df['math_score_bin'].value_counts()

plt.figure(figsize=(10,6))
plt.pie(math_score_counts, labels = math_score_counts.index, autopct='%1.1f%%')
plt.title('Pie chart of math scores')
plt.show()

# %%
sns.relplot(x="race/ethnicity", y="math score", data=df,kind = "line", hue="gender")

# %%
sns.relplot(x="race/ethnicity", y="lunch", data=df,kind = "line", hue="gender")

# %%
# Convert 'parental level of education' to numerical values
education_levels = {'some high school': 1, 'high school': 2, 'some college': 3, 'associate\'s degree': 4, 'bachelor\'s degree': 5, 'master\'s degree': 6}
df['parental level of education'] = df['parental level of education'].map(education_levels)

# Create the bar plot
sns.catplot(x="test preparation course", y="parental level of education", data=df, kind="bar", hue="gender")

# %%
sns.catplot(x="test preparation course", y="parental level of education", data=df, kind="point", hue="gender")

# %%
sns.catplot(x="test preparation course", y="math score", data=df, kind="bar", hue="gender", row="race/ethnicity")
